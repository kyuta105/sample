# %% [markdown]
# # 練習

# %% [markdown]
# ## 色々

# %%
x = 1
x
# Out:
# 1

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
numbers = [10, 20, 30]

for n in numbers:
    print(n)
# Out:
# 10
# 20
# 30

# %%
for c in "python":
    print(c)
# Out:
# p
# y
# t
# h
# o
# n

# %%
total = 0

for i in range(1,6):
    total += i

print(total)
# Out:
# 15

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
